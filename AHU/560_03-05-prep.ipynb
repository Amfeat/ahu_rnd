# %%
import pandas as pd
# %matplotlib tk
pd.options.plotting.backend = "plotly"
import matplotlib.pyplot as plt

df = pd.read_csv('db_pool/560_03-05.csv', index_col='Unnamed: 0')

# %%
zero_std = []
for col in df.columns:
    if df[col].std() == 0:
        zero_std.append(col)
df = df.drop(columns=zero_std)
zero_std.sort()
# zero_std

# %%
full_df = df
# df.describe()

# %%
df.index = df.index - 3600*5
df.index = pd.to_datetime(df.index, unit='s')
collist = []
for col in df.columns:
    collist.append(col)
collist.sort()
# collist

# %%
# collist

# %%
actual_columns = [
 'AC03R_kWh',
 'AC03S_Current',
 'AC03S_Frequency',
 'AC03S_kWh',
 'B4E_AC3S_NantumRampDown',
 'B4E_AC3_SAT_SP',
 'B4E_AC3_SAT_SP_enable',
 'B4E_AC3_SAT_SPmax',
 'B4E_AC3_SAT_SPmin',
 'B4E_AC3_Static_SP',
 'B4E_AC3_Static_SP_enable',
 'B4E_AC3_Static_SPmin',
 'CoolingVlv_AC3S',
 'Current$2eAC3S',
 'Current$2eAc3R',
 'Current.Ac3R',
 'DriveStat$2eAc3R',
 'DriveStat.Ac3R',
 'EconEnable$2eAC3S',
 'Economizer$2eAC3S',
 'Frequency$2eAC3S',
 'Frequency$2eAc3R',
 'Frequency.Ac3R',
 'MinDmpPos$2eAC3S',
 'MinDpMinPos$2eAC3S',
 'NanStatStpt_AC3S',
 'NanSupStpt_AC3S',
 'OAH',
 'OAT',
 'OA_CO2',
 'Power$2eAc3R',
 'Power$2eAc3S',
 'Power.Ac3R',
 'Power.Ac3S',
 'ReturnCO2.AC3',
 'ReturnRH$2eAC3S',
 'ReturnTemp.AC3',
 'SpaceRH$2eAC3S',
 'SpaceTemp.AC3',
 'StatStpt_AC3S',
 'StaticPress_AC3S',
 'SupFanStat.AC3',
 'SupStpt_AC3S',
 'SupplyTemp$2eAC3',
 'SupplyTemp.AC3',
 'cloudiness',
 'humidity',
 'surface_shortwave_radiation',
 'temperature',
 'wind_direction',
 'wind_speed'
]

vav_columns = [
#  'Current.Ac3R',
#  'Frequency.Ac3R',
#  'OAH',
#  'OAT',
#  'Power.Ac3R',
#  'Power.Ac3S',
#  'ReturnCO2.AC3',
#  'ReturnTemp.AC3',
#  'SpaceTemp.AC3',
#  'SupplyTemp.AC3',
#  'VAV_03_01 DamperPos',
#  'VAV_03_01 Flow',
#  'VAV_03_01 FlowStpt',
#  'VAV_03_01 SpaceTemp',
#  'VAV_03_02 DamperPos',
#  'VAV_03_02 Flow',
#  'VAV_03_02 FlowStpt',
#  'VAV_03_02 SpaceTemp',
#  'VAV_03_03 DamperPos',
#  'VAV_03_03 Flow',
#  'VAV_03_03 FlowStpt',
#  'VAV_03_03 SpaceTemp',
#  'VAV_03_04 DamperPos',
#  'VAV_03_04 Flow',
#  'VAV_03_04 FlowStpt',
#  'VAV_03_04 SpaceTemp',
#  'VAV_03_05 DamperPos',
#  'VAV_03_05 Flow',
#  'VAV_03_05 FlowStpt',
#  'VAV_03_05 SpaceTemp',
#  'VAV_03_06 BldgSpaceTemp',
#  'VAV_03_06 DamperPos',
#  'VAV_03_06 Flow',
#  'VAV_03_06 FlowStpt',
#  'VAV_03_06 SpaceTemp',
#  'VAV_03_07 DamperPos',
#  'VAV_03_07 Flow',
#  'VAV_03_07 FlowStpt',
#  'VAV_03_07 SpaceTemp',
#  'VAV_03_08 DamperPos',
#  'VAV_03_08 Flow',
#  'VAV_03_08 FlowStpt',
#  'VAV_03_08 SpaceTemp',
#  'VAV_03_09 BldgSpaceTemp',
#  'VAV_03_09 DamperPos',
#  'VAV_03_09 Flow',
#  'VAV_03_09 FlowStpt',
#  'VAV_03_09 SpaceTemp',
#  'VAV_03_10 DamperPos',
#  'VAV_03_10 Flow',
#  'VAV_03_10 FlowStpt',
#  'VAV_03_10 SpaceTemp',
#  'VAV_03_11 DamperPos',
#  'VAV_03_11 Flow',
#  'VAV_03_11 FlowStpt',
#  'VAV_03_11 SpaceTemp',
#  'VAV_03_12 DamperPos',
#  'VAV_03_12 Flow',
#  'VAV_03_12 FlowStpt',
#  'VAV_03_12 SpaceTemp',
#  'VAV_03_13 DamperPos',
#  'VAV_03_13 Flow',
#  'VAV_03_13 FlowStpt',
#  'VAV_03_13 SpaceTemp',
#  'VAV_03_14 DamperPos',
#  'VAV_03_14 Flow',
#  'VAV_03_14 FlowStpt',
#  'VAV_03_14 SpaceTemp',
#  'VAV_03_15 DamperPos',
#  'VAV_03_15 Flow',
#  'VAV_03_15 FlowStpt',
#  'VAV_03_15 SpaceTemp',
 'VAV_03_16 DamperPos',
 'VAV_03_16 Flow',
 'VAV_03_16 FlowStpt',
 'VAV_03_16 SpaceTemp',
#  'VAV_03_17 DamperPos',
#  'VAV_03_17 Flow',
#  'VAV_03_17 FlowStpt',
#  'VAV_03_17 SpaceTemp',
#  'VAV_03_18 DamperPos',
#  'VAV_03_18 Flow',
#  'VAV_03_18 FlowStpt',
#  'VAV_03_18 SpaceTemp',
#  'VAV_03_19 DamperPos',
#  'VAV_03_19 Flow',
#  'VAV_03_19 FlowStpt',
#  'VAV_03_19 SpaceTemp',
#  'VAV_03_20 DamperPos',
#  'VAV_03_20 Flow',
#  'VAV_03_20 FlowStpt',
#  'VAV_03_20 SpaceTemp',
#  'VAV_03_21 DamperPos',
#  'VAV_03_21 Flow',
#  'VAV_03_21 FlowStpt',
#  'VAV_03_21 SpaceTemp',
#  'VAV_03_22 DamperPos',
#  'VAV_03_22 Flow',
#  'VAV_03_22 FlowStpt',
#  'VAV_03_22 SpaceTemp',
#  'VAV_03_23 DamperPos',
#  'VAV_03_23 Flow',
#  'VAV_03_23 FlowStpt',
#  'VAV_03_23 SpaceTemp',
#  'VAV_03_24 DamperPos',
#  'VAV_03_24 Flow',
#  'VAV_03_24 FlowStpt',
#  'VAV_03_24 SpaceTemp',
#  'VAV_03_25 DamperPos',
#  'VAV_03_25 Flow',
#  'VAV_03_25 FlowStpt',
#  'VAV_03_25 SpaceTemp',
#  'VAV_03_26 DamperPos',
#  'VAV_03_26 Flow',
#  'VAV_03_26 FlowStpt',
#  'VAV_03_26 SpaceTemp',
]

# %%
flow_columns = []
for name in  df.columns:
    if name.endswith('Flow'):
        flow_columns.append(name)
# flow_columns

# %%
# FlowStpt
fstp_columns = []
for name in  full_df.columns:
#     print(name)
    if name.endswith('FlowStpt'):
        fstp_columns.append(name)
# fstp_columns

# %%
temp_columns = []
for name in  full_df.columns:
    if name.endswith('SpaceTemp'):
        temp_columns.append(name)
# temp_columns

# %%
df = full_df[actual_columns].copy()
df.loc[:, 'Total_flow'] = full_df[flow_columns].sum(axis=1)
df.loc[:, 'Total_flow_stpt'] = full_df[fstp_columns].sum(axis=1)
df[['Total_flow', 'Total_flow_stpt']].plot()
# Out:
# <div>                            <div id="31110c12-3b4e-4129-800e-55d2544f6e5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31110c12-3b4e-4129-800e-55d2544f6e5d")) {                    Plotly.newPlot(                        "31110c12-3b4e-4129-800e-55d2544f6e5d",                        [{"hovertemplate": "variable=Total_flow<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Total_flow", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Total_flow", "showlegend": true, "type": "scattergl", "x": ["2021-04-11T14:00:00", "2021-04-11T14:10:00", "2021-04-11T14:20:00", "2021-04-11T14:30:00", "2021-04-11T14:40:00", "2021-04-11T14:50:00", "2021-04-11T15:00:00", "2021-04-11T15:10:00", "2021-04-11T15:20:00", "2021-04-11T15
# ...

# %%
df = full_df.copy()
# df.loc[:, 'Total_flow'] = full_df[flow_columns].sum(axis=1)
# df.loc[:, 'Total_flow_stpt'] = full_df[fstp_columns].sum(axis=1)
df[['VAV_03_16 Flow', 'VAV_03_16 FlowStpt']].plot()

#  'VAV_03_16 DamperPos',
#  'VAV_03_16 Flow',
#  'VAV_03_16 FlowStpt',
#  'VAV_03_16 SpaceTemp',
# Out:
# <div>                            <div id="77e48f2d-60e4-43fb-98f0-6310f6518257" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77e48f2d-60e4-43fb-98f0-6310f6518257")) {                    Plotly.newPlot(                        "77e48f2d-60e4-43fb-98f0-6310f6518257",                        [{"hovertemplate": "variable=VAV_03_16 Flow<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "VAV_03_16 Flow", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "VAV_03_16 Flow", "showlegend": true, "type": "scattergl", "x": ["2021-04-11T14:00:00", "2021-04-11T14:10:00", "2021-04-11T14:20:00", "2021-04-11T14:30:00", "2021-04-11T14:40:00", "2021-04-11T14:50:00", "2021-04-11T15:00:00", "2021-04-11T15:10:00", "2021-04-11T15:20:00", "2
# ...

# %%
df = df.copy()
df.loc[:,'temp_delta'] = full_df["ReturnTemp.AC3"] - full_df["SupplyTemp.AC3"]
df.loc[:,'Q_load'] = df['temp_delta'] * df['Total_flow']
# df[['temp_delta', 'Q_load', 'Total_flow', 'OAT']].plot()

# %%
df.loc[:,'median_space_temp'] = full_df[temp_columns].median(axis=1)

# %%
df = df.copy()
df.loc[:,'resampled'] = df['median_space_temp']
df.loc[:,'resampled'] = df['resampled'].resample('100T').interpolate(method='spline', order=5)

df.loc[:,'resampled'] = df.resampled.interpolate(method='time', order = 1)

# df[['resampled', 'median_space_temp']].plot()

# %%
import numpy as np
tmp_ = df['resampled']
slope = pd.Series(np.gradient(tmp_.values), tmp_.index, name='slope')


df.loc[:,'der'] = slope
# df['der'].plot()

# %%
df.columns
# Out:
# Index(['AC03R_kWh', 'AC03S_Current', 'AC03S_Frequency', 'AC03S_kWh',
#        'B4E_AC3S_NantumRampDown', 'B4E_AC3_SAT_SP', 'B4E_AC3_SAT_SP_enable',
#        'B4E_AC3_SAT_SPmax', 'B4E_AC3_SAT_SPmin', 'B4E_AC3_Static_SP',
#        'B4E_AC3_Static_SP_enable', 'B4E_AC3_Static_SPmin', 'CoolingVlv_AC3S',
#        'Current$2eAC3S', 'Current$2eAc3R', 'Current.Ac3R', 'DriveStat$2eAc3R',
#        'DriveStat.Ac3R', 'EconEnable$2eAC3S', 'Economizer$2eAC3S',
#        'Frequency$2eAC3S', 'Frequency$2eAc3R', 'Frequency.Ac3R',
#        'MinDmpPos$2eAC3S', 'MinDpMinPos$2eAC3S', 'NanStatStpt_AC3S',
#        'NanSupStpt_AC3S', 'OAH', 'OAT', 'OA_CO2', 'Power$2eAc3R',
#        'Power$2eAc3S', 'Power.Ac3R', 'Power.Ac3S', 'ReturnCO2.AC3',
#        'ReturnRH$2eAC3S', 'ReturnTemp.AC3', 'SpaceRH$2eAC3S', 'SpaceTemp.AC3',
#        'StatStpt_AC3S', 'StaticPress_AC3S', 'SupFanStat.AC3', 'SupStpt_AC3S',
#        'SupplyTemp$2eAC3', 'SupplyTemp.AC3', 'cloudiness', 'humidity',
# ...

# %%
df.to_csv('560-04-05_ahu.csv')

# %%
df.plot.scatter(x='OAT', y='Q_load', c='DarkBlue')
# Out:
# <div>                            <div id="126b9c0c-1a0b-4630-bf33-1752283e1854" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("126b9c0c-1a0b-4630-bf33-1752283e1854")) {                    Plotly.newPlot(                        "126b9c0c-1a0b-4630-bf33-1752283e1854",                        [{"hovertemplate": "OAT=%{x}<br>Q_load=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [55.98823547363281, 55.73235244750978, 55.71764602661133, 56.0500015258789, 56.09705886840821, 56.07058868408203, 56.1058822631836, 56.47941207885742, 56.60882339477539, 56.63235321044922, 56.62352905273438, 56.56176605224609, 56.105883026123045, 55.84705734
# ...

# %%
import plotly.graph_objs as go
from plotly.offline import iplot
# go.Scatter3d(x='temp_delta', y='Q_load', c='DarkBlue')
plot_df = df.query('OAT > 0 and Total_flow > 0')
trace = go.Scatter3d(
   x = plot_df['Total_flow'], y = plot_df['der'], z = plot_df['temp_delta'],mode = 'markers', marker = dict(
      size = 1,
      color = plot_df['Total_flow'], # set color to an array/list of desired values
      colorscale = 'Viridis'
      )
   )
layout = go.Layout(title = '3D Scatter plot')
fig = go.Figure(data = [trace], layout = layout)
iplot(fig)
# Out:
# <div>                            <div id="c8bcdcd4-2949-4467-9265-a8d0d8d94a76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8bcdcd4-2949-4467-9265-a8d0d8d94a76")) {                    Plotly.newPlot(                        "c8bcdcd4-2949-4467-9265-a8d0d8d94a76",                        [{"marker": {"color": [2718.160188293457, 3008.678031158447, 2933.9640228271487, 2959.7408187866213, 2846.678618621826, 2766.874655151367, 3034.863256835937, 2839.9220703124997, 2830.380642700195, 2811.4388877868655, 2933.6449256896976, 2706.272853851319, 2958.9105895996095, 2941.5388175964354, 2966.2975440979003, 2880.110639953613, 2765.5238380432124, 2713.991144561767, 1164.987403869629, 4516.945419311523, 4552.015194702149, 2845.442473602295, 2987.1922225952144
# ...

# %%
df.plot.scatter(x='der', y='Q_load', c='DarkBlue')
# Out:
# <div>                            <div id="f459dda3-d1d7-4ad1-b551-9265f200fbbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f459dda3-d1d7-4ad1-b551-9265f200fbbd")) {                    Plotly.newPlot(                        "f459dda3-d1d7-4ad1-b551-9265f200fbbd",                        [{"hovertemplate": "der=%{x}<br>Q_load=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [null, null, null, null, null, null, null, 0.010199890136718182, 0.010199890136718182, 0.010199890136718182, 0.010199890136718182, 0.010199890136711076, 0.010199890136711076, 0.010199890136718182, 0.010199890136718182, 0.010199890136718182, 0.019199905395510
# ...

# %%
df['ReturnTemp'] = df['ReturnTemp.AC3']
plot_df = df.query('OAT > 0 and Total_flow > 0 and -0.1 < der < 0.1 and 72 < ReturnTemp < 75')
trace = go.Scatter3d(
   x = plot_df['der'], y = plot_df['OAT'], z = plot_df['Q_load'],mode = 'markers', marker = dict(
      size = 1,
      color = plot_df['temp_delta'], # set color to an array/list of desired values
      colorscale = 'Viridis'
      )
   )
layout = go.Layout(title = '3D Scatter plot')
fig = go.Figure(data = [trace], layout = layout)
iplot(fig)
# Out:
# <ipython-input-30-78db0dd23f38>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
plot_df.plot.scatter(x='OAT', y='Q_load', c='DarkBlue')
# Out:
# <div>                            <div id="9e695ddc-cfd6-4c85-aafd-cc4efbf727e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e695ddc-cfd6-4c85-aafd-cc4efbf727e0")) {                    Plotly.newPlot(                        "9e695ddc-cfd6-4c85-aafd-cc4efbf727e0",                        [{"hovertemplate": "OAT=%{x}<br>Q_load=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [72.30882263183594, 72.48529434204102, 72.9117660522461, 73.17646789550781, 73.3161735534668, 73.95588302612305, 74.26470565795898, 77.13970565795898, 77.66912078857422, 77.70588302612305, 77.11029434204102, 76.83088302612305, 76.55146789550781, 76.338233947
# ...

# %%
vdf = full_df[vav_columns]

# %%
vdf.plot()

# %%
df[actual_columns]['2020-08-08 00:00':].plot()

# %%
import seaborn as sns

sns.heatmap(vdf.corr());

# %%
vdf.columns

# %%
vdf.plot.scatter(x='VAV_03_01 DamperPos', y='VAV_03_01 FlowStpt', c='DarkBlue')

# %%
vdf.plot.scatter(x='VAV_03_01 SpaceTemp', y='VAV_03_01 FlowStpt', c='DarkBlue')

# %%
vdf.plot.scatter(x='VAV_03_01 Flow', y='VAV_03_01 FlowStpt', c='DarkBlue')

# %%
vdf.plot.scatter(x='VAV_03_01 Flow', y='VAV_03_01 DamperPos', c='DarkBlue')

# %%
df.query('10 > chiller_delta > 3.11 and Common_CHWS < 52').plot.scatter(x="OAT", y="cooler_delta", c='DarkBlue')

# %%
df.query('10 > chiller_delta > 3.11 and Common_CHWS < 52').plot.scatter(x="OAT", y="Common_CWR", c='DarkBlue')

# %%
sns.heatmap(df.query('10 > chiller_delta > 3.11 and Common_CHWS < 52').corr());

# %%
df.query('10 > chiller_delta > 3.11 and Common_CHWS < 52').plot()
